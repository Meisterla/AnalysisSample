# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('C:/Users/Administrator/Desktop/anime.csv')

# %%
df.head()
# Out:
#                                           anime_cast anime_company  \
# 0                           川原庆久|能登麻美子|花泽香菜|石田彰|小西克幸  A-1 Pictures
# 1                        林原惠美|绿川光|若本规夫|山寺宏一|石冢运升|中博史          日昇动画
# 2  宫野真守|阪口大助|大塚明夫|钉宫理惠|绿川光|宫本充|石田彰|石冢运升|藤原启治|小林优|...         BONES
# 3  本田贵子|大原沙耶香|丰崎爱生|逢坂良太|金元寿子|鸟海浩辅|田中敦子|喜多村英梨|新井里美...           NaN
# 4  东山奈央|江口拓也|近藤隆|井上麻里奈|小清水亚美|小松未可子|悠木碧|柚木凉香|早见沙织|...         feel.
#
#        anime_name anime_region  anime_set_number anime_status     anime_tag  \
# 0       妖精的尾巴ZERO           日本                12           完结         热血|冒险
# 1            星际牛仔           日本                27          NaN      冒险|励志|动作
# 2            血界战线           日本                14           完结      热血|冒险|奇幻
# 3  希德尼娅的骑士 第9行星战役           日本                12           完结         科幻|机战
# 4  我的青春恋爱物语果然有问题。           日本                14           完结  搞笑|青春|轻小说|恋爱
#
#                                       anime_url      anime_view anime_year  \
# ...

# %%
df.describe()
# Out:
#        anime_set_number
# count       2283.000000
# mean          18.941305
# std           33.479899
# min            0.000000
# 25%           12.000000
# 50%           13.000000
# 75%           24.000000
# max          911.000000

# %%
df.to_excel(excel_writer='C:/Users/Administrator/Desktop/anime.xlsx',sheet_name='anime',index=False,encoding='utf-8')
